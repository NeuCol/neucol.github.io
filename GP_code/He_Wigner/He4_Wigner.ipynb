# %%
# We need PyTorch and GPyTorch
import torch
from torch import Tensor
import gpytorch
# Gaussian processes really don't work well without 64-bit precision
torch.set_default_dtype(torch.float64)
# For reproducibility:
torch.random.manual_seed(12345)
import sys
sys.path.append("..")

from norm_constrain import Norm2ConstrainedContainer_SE, Norm2ConstrainedContainer_rational, Norm2ConstrainedContainer_ConvexCombination, Norm2ConstrainedContainer_KroneckerProduct

# And a few more players
import numpy as np
from scipy.integrate import quad
from matplotlib import pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline

# %%
# Import the data, check normalization, which should be \pi/2

with open('wgn.VMC_1.nucl.he4', 'r') as fd:
    lines = fd.readlines()
    
nk = 100 ; nr = 201
x = [] ; y = [] ; err = []
for line in lines[3:]:
    buf = line.split()
    x.append([float(buf[1]),float(buf[0])])
    y.append(float(buf[2]))
    err.append(float(buf[3]))
x = np.array(x) ; y = np.array(y) ; err = np.array(err)
xx = x.reshape((nr,nk,-1)) ; yy=y.reshape((nr,nk)) ; errr=err.reshape((nr,nk))
print(xx.shape)
print(yy.shape)
dr = xx[1,0,0] - xx[0,0,0] ; dk = xx[0,2,1] - xx[0,1,1] ; delta = np.array([dr, dk])
print(delta)

xx = xx[1:,1:,:] - delta/2 # Cell centers
br = (yy[1:,1:] - yy[:-1,1:])/dr ; bk = (yy[1:,1:] - yy[1:,:-1])/dk
beta = np.array([br,bk]).transpose((1,2,0))
print(beta.shape)
yy = yy[1:,1:] - 0.5 * beta.dot(delta) # Interpolation to cell centers

ig = (yy * xx[:,:,0]**2 * xx[:,:,1]**2).sum() *dk*dr *2 / np.pi
print("Integral / (pi/2) = %f"%ig)
# Out:
# (201, 100, 2)
# (201, 100)
# [0.025 0.08 ]
# (200, 99, 2)
# Integral / (pi/2) = 1.006803

# %%
# Subsample training data
subrate = 5 # per dimension, full subsampling rate is square of this
train_x = torch.tensor(xx[::subrate,::subrate,:]).reshape(-1,2)
train_y = torch.tensor(yy[::subrate,::subrate]).flatten()
train_err = torch.tensor(errr[::subrate,::subrate]).flatten()**2
print(train_x.shape)

# Normalization value
nval = np.pi/2
# Out:
# torch.Size([800, 2])

# %%
# Create the GPyTorch model
class GPRegressionModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood, nval):
        super(GPRegressionModel, self).__init__(train_x, train_y, likelihood)

        self.nm0_0 = Norm2ConstrainedContainer_SE()
        self.nm0_0.sigma = 0.292 ; self.nm0_0.gamma = 3.432 ; self.nm0_0.A = 0.426
        self.nm0_1 = Norm2ConstrainedContainer_SE(fix_amplitude=1.0)
        self.nm0_1.sigma = 0.919 ; self.nm0_1.gamma = 2.379
        kernels = [self.nm0_0,self.nm0_1]
        self.nm0 = Norm2ConstrainedContainer_KroneckerProduct(kernels, norm_val=nval)

        self.covar_module = self.nm0.covar_module
        self.mean_module = self.nm0.mean_module

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

likelihood = gpytorch.likelihoods.FixedNoiseGaussianLikelihood(noise=train_err)

model = GPRegressionModel(train_x, train_y, likelihood, nval)
# Out:
# /home/carlo/python_venvs/pytorch.venv/lib/python3.10/site-packages/gpytorch/likelihoods/noise_models.py:148: NumericalWarning: Very small noise values detected. This will likely lead to numerical instabilities. Rounding small noise values up to 1e-06.
#   warnings.warn(

# %%
# Training
training_iter = 500

model.train()
likelihood.train()

# Use the adam optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.1)  # Includes GaussianLikelihood parameters

# "Loss" for GPs - the marginal log likelihood
mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

for i in range(training_iter):
    # Zero gradients from previous iteration
    optimizer.zero_grad()
    # Output from model
    output = model(train_x)
    # Calc loss and backprop gradients
    loss = -mll(output, train_y)
    loss.backward()
    print('Iter %d/%d - Loss: %.3f\nSE_k: sigma: %.3f  gamma: %.3f  A: %.3f\nSE_r: sigma: %.3f  gamma: %.3f' % (
        i + 1, training_iter, loss.item(),
        model.nm0.kernels[0].sigma.item(),
        model.nm0.kernels[0].gamma.item(),
        model.nm0.kernels[0].A.item(),
        model.nm0.kernels[1].sigma.item(),
        model.nm0.kernels[1].gamma.item(),
    ))
    optimizer.step()
# Out:
# /home/carlo/python_venvs/pytorch.venv/lib/python3.10/site-packages/gpytorch/likelihoods/gaussian_likelihood.py:300: GPInputWarning: You have passed data through a FixedNoiseGaussianLikelihood that did not match the size of the fixed noise, *and* you did not specify noise. This is treated as a no-op.
#   warnings.warn(
# Iter 1/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 2/500 - Loss: -5.367
# SE_k: sigma: 0.268  gamma: 3.529  A: 0.462
# SE_r: sigma: 0.860  gamma: 2.470
# Iter 3/500 - Loss: -5.843
# SE_k: sigma: 0.285  gamma: 3.458  A: 0.435
# SE_r: sigma: 0.903  gamma: 2.403
# Iter 4/500 - Loss: -4.796
# SE_k: sigma: 0.306  gamma: 3.378  A: 0.407
# SE_r: sigma: 0.953  gamma: 2.328
# Iter 5/500 - Loss: -5.907
# SE_k: sigma: 0.294  gamma: 3.424  A: 0.423
# SE_r: sigma: 0.924  gamma: 2.372
# Iter 6/500 - Loss: -5.798
# SE_k: sigma: 0.283  gamma: 3.465  A: 0.437
# SE_r: sigma: 0.900  gamma: 2.411
# Iter 7/500 - Loss: -5.594
# SE_k: sigma: 0.275  gamma: 3.496  A: 0.448
# SE_r: sigma: 0.882  gamma: 2.441
# Iter 8/500 - Loss: -5.437
# SE_k: sigma: 0.269  gamma: 3.517  A: 0.455
# SE_r: sigma: 0.870  gamma: 2.462
# Iter 9/500 - Loss: -5.338
# SE_k: sigma: 0.265  gamma: 3.529  A: 0.458
# SE_r: sigma: 0.864  gamma: 2.475
# Iter 10/500 - Loss: -5.290
# SE_k: sigma: 0.263  gamma: 3.534  A: 0.459
# SE_r: sigma: 0.863  gamma: 2.482
# Iter 11/500 - Loss: -5.286
# SE_k: sigma: 0.262  gamma: 3.533  A: 0.456
# SE_r: sigma: 0.865  gamma: 2.484
# Iter 12/500 - Loss: -5.321
# SE_k: sigma: 0.262  gamma: 3.526  A: 0.452
# SE_r: sigma: 0.871  gamma: 2.480
# Iter 13/500 - Loss: -5.389
# SE_k: sigma: 0.264  gamma: 3.514  A: 0.446
# SE_r: sigma: 0.880  gamma: 2.472
# Iter 14/500 - Loss: -5.487
# SE_k: sigma: 0.266  gamma: 3.498  A: 0.438
# SE_r: sigma: 0.892  gamma: 2.460
# Iter 15/500 - Loss: -5.607
# SE_k: sigma: 0.269  gamma: 3.479  A: 0.429
# SE_r: sigma: 0.906  gamma: 2.445
# Iter 16/500 - Loss: -5.737
# SE_k: sigma: 0.273  gamma: 3.456  A: 0.419
# SE_r: sigma: 0.923  gamma: 2.427
# Iter 17/500 - Loss: -5.852
# SE_k: sigma: 0.278  gamma: 3.430  A: 0.409
# SE_r: sigma: 0.941  gamma: 2.406
# Iter 18/500 - Loss: -5.893
# SE_k: sigma: 0.283  gamma: 3.405  A: 0.399
# SE_r: sigma: 0.958  gamma: 2.385
# Iter 19/500 - Loss: -5.782
# SE_k: sigma: 0.288  gamma: 3.383  A: 0.391
# SE_r: sigma: 0.973  gamma: 2.366
# Iter 20/500 - Loss: -5.631
# SE_k: sigma: 0.290  gamma: 3.373  A: 0.388
# SE_r: sigma: 0.978  gamma: 2.355
# Iter 21/500 - Loss: -5.724
# SE_k: sigma: 0.290  gamma: 3.380  A: 0.390
# SE_r: sigma: 0.971  gamma: 2.357
# Iter 22/500 - Loss: -5.872
# SE_k: sigma: 0.287  gamma: 3.398  A: 0.395
# SE_r: sigma: 0.955  gamma: 2.368
# Iter 23/500 - Loss: -5.906
# SE_k: sigma: 0.283  gamma: 3.419  A: 0.402
# SE_r: sigma: 0.939  gamma: 2.380
# Iter 24/500 - Loss: -5.871
# SE_k: sigma: 0.281  gamma: 3.438  A: 0.409
# SE_r: sigma: 0.923  gamma: 2.391
# Iter 25/500 - Loss: -5.824
# SE_k: sigma: 0.279  gamma: 3.452  A: 0.414
# SE_r: sigma: 0.911  gamma: 2.399
# Iter 26/500 - Loss: -5.792
# SE_k: sigma: 0.278  gamma: 3.461  A: 0.418
# SE_r: sigma: 0.902  gamma: 2.402
# Iter 27/500 - Loss: -5.785
# SE_k: sigma: 0.279  gamma: 3.465  A: 0.419
# SE_r: sigma: 0.897  gamma: 2.401
# Iter 28/500 - Loss: -5.802
# SE_k: sigma: 0.280  gamma: 3.464  A: 0.419
# SE_r: sigma: 0.895  gamma: 2.397
# Iter 29/500 - Loss: -5.838
# SE_k: sigma: 0.282  gamma: 3.459  A: 0.418
# SE_r: sigma: 0.896  gamma: 2.389
# Iter 30/500 - Loss: -5.880
# SE_k: sigma: 0.285  gamma: 3.451  A: 0.415
# SE_r: sigma: 0.899  gamma: 2.378
# Iter 31/500 - Loss: -5.910
# SE_k: sigma: 0.289  gamma: 3.441  A: 0.412
# SE_r: sigma: 0.903  gamma: 2.367
# Iter 32/500 - Loss: -5.904
# SE_k: sigma: 0.292  gamma: 3.430  A: 0.409
# SE_r: sigma: 0.908  gamma: 2.355
# Iter 33/500 - Loss: -5.864
# SE_k: sigma: 0.295  gamma: 3.422  A: 0.406
# SE_r: sigma: 0.912  gamma: 2.348
# Iter 34/500 - Loss: -5.844
# SE_k: sigma: 0.296  gamma: 3.419  A: 0.406
# SE_r: sigma: 0.914  gamma: 2.347
# Iter 35/500 - Loss: -5.876
# SE_k: sigma: 0.295  gamma: 3.422  A: 0.408
# SE_r: sigma: 0.912  gamma: 2.353
# Iter 36/500 - Loss: -5.909
# SE_k: sigma: 0.293  gamma: 3.429  A: 0.412
# SE_r: sigma: 0.908  gamma: 2.363
# Iter 37/500 - Loss: -5.913
# SE_k: sigma: 0.291  gamma: 3.436  A: 0.415
# SE_r: sigma: 0.904  gamma: 2.375
# Iter 38/500 - Loss: -5.899
# SE_k: sigma: 0.289  gamma: 3.441  A: 0.418
# SE_r: sigma: 0.901  gamma: 2.385
# Iter 39/500 - Loss: -5.884
# SE_k: sigma: 0.288  gamma: 3.444  A: 0.421
# SE_r: sigma: 0.900  gamma: 2.392
# Iter 40/500 - Loss: -5.880
# SE_k: sigma: 0.288  gamma: 3.443  A: 0.421
# SE_r: sigma: 0.901  gamma: 2.396
# Iter 41/500 - Loss: -5.888
# SE_k: sigma: 0.289  gamma: 3.440  A: 0.421
# SE_r: sigma: 0.904  gamma: 2.396
# Iter 42/500 - Loss: -5.903
# SE_k: sigma: 0.290  gamma: 3.433  A: 0.419
# SE_r: sigma: 0.909  gamma: 2.394
# Iter 43/500 - Loss: -5.915
# SE_k: sigma: 0.292  gamma: 3.425  A: 0.417
# SE_r: sigma: 0.915  gamma: 2.390
# Iter 44/500 - Loss: -5.915
# SE_k: sigma: 0.294  gamma: 3.417  A: 0.415
# SE_r: sigma: 0.920  gamma: 2.386
# Iter 45/500 - Loss: -5.904
# SE_k: sigma: 0.295  gamma: 3.411  A: 0.413
# SE_r: sigma: 0.925  gamma: 2.382
# Iter 46/500 - Loss: -5.896
# SE_k: sigma: 0.296  gamma: 3.408  A: 0.413
# SE_r: sigma: 0.927  gamma: 2.380
# Iter 47/500 - Loss: -5.902
# SE_k: sigma: 0.295  gamma: 3.409  A: 0.414
# SE_r: sigma: 0.927  gamma: 2.382
# Iter 48/500 - Loss: -5.912
# SE_k: sigma: 0.294  gamma: 3.413  A: 0.416
# SE_r: sigma: 0.924  gamma: 2.386
# Iter 49/500 - Loss: -5.916
# SE_k: sigma: 0.292  gamma: 3.419  A: 0.418
# SE_r: sigma: 0.921  gamma: 2.390
# Iter 50/500 - Loss: -5.912
# SE_k: sigma: 0.291  gamma: 3.424  A: 0.420
# SE_r: sigma: 0.918  gamma: 2.393
# Iter 51/500 - Loss: -5.907
# SE_k: sigma: 0.290  gamma: 3.427  A: 0.422
# SE_r: sigma: 0.916  gamma: 2.395
# Iter 52/500 - Loss: -5.906
# SE_k: sigma: 0.290  gamma: 3.428  A: 0.423
# SE_r: sigma: 0.915  gamma: 2.394
# Iter 53/500 - Loss: -5.909
# SE_k: sigma: 0.290  gamma: 3.427  A: 0.422
# SE_r: sigma: 0.916  gamma: 2.391
# Iter 54/500 - Loss: -5.914
# SE_k: sigma: 0.291  gamma: 3.424  A: 0.422
# SE_r: sigma: 0.918  gamma: 2.387
# Iter 55/500 - Loss: -5.917
# SE_k: sigma: 0.291  gamma: 3.421  A: 0.421
# SE_r: sigma: 0.920  gamma: 2.382
# Iter 56/500 - Loss: -5.915
# SE_k: sigma: 0.292  gamma: 3.417  A: 0.420
# SE_r: sigma: 0.922  gamma: 2.377
# Iter 57/500 - Loss: -5.912
# SE_k: sigma: 0.293  gamma: 3.416  A: 0.419
# SE_r: sigma: 0.923  gamma: 2.374
# Iter 58/500 - Loss: -5.911
# SE_k: sigma: 0.293  gamma: 3.416  A: 0.420
# SE_r: sigma: 0.922  gamma: 2.373
# Iter 59/500 - Loss: -5.914
# SE_k: sigma: 0.292  gamma: 3.418  A: 0.421
# SE_r: sigma: 0.921  gamma: 2.373
# Iter 60/500 - Loss: -5.917
# SE_k: sigma: 0.291  gamma: 3.422  A: 0.423
# SE_r: sigma: 0.918  gamma: 2.375
# Iter 61/500 - Loss: -5.917
# SE_k: sigma: 0.290  gamma: 3.426  A: 0.424
# SE_r: sigma: 0.916  gamma: 2.378
# Iter 62/500 - Loss: -5.915
# SE_k: sigma: 0.290  gamma: 3.428  A: 0.425
# SE_r: sigma: 0.914  gamma: 2.379
# Iter 63/500 - Loss: -5.913
# SE_k: sigma: 0.290  gamma: 3.429  A: 0.426
# SE_r: sigma: 0.914  gamma: 2.380
# Iter 64/500 - Loss: -5.914
# SE_k: sigma: 0.290  gamma: 3.429  A: 0.426
# SE_r: sigma: 0.914  gamma: 2.379
# Iter 65/500 - Loss: -5.916
# SE_k: sigma: 0.290  gamma: 3.427  A: 0.426
# SE_r: sigma: 0.915  gamma: 2.377
# Iter 66/500 - Loss: -5.917
# SE_k: sigma: 0.291  gamma: 3.425  A: 0.425
# SE_r: sigma: 0.917  gamma: 2.375
# Iter 67/500 - Loss: -5.916
# SE_k: sigma: 0.291  gamma: 3.423  A: 0.425
# SE_r: sigma: 0.919  gamma: 2.373
# Iter 68/500 - Loss: -5.915
# SE_k: sigma: 0.292  gamma: 3.421  A: 0.424
# SE_r: sigma: 0.920  gamma: 2.372
# Iter 69/500 - Loss: -5.915
# SE_k: sigma: 0.292  gamma: 3.421  A: 0.425
# SE_r: sigma: 0.920  gamma: 2.373
# Iter 70/500 - Loss: -5.916
# SE_k: sigma: 0.292  gamma: 3.422  A: 0.425
# SE_r: sigma: 0.919  gamma: 2.374
# Iter 71/500 - Loss: -5.917
# SE_k: sigma: 0.291  gamma: 3.424  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.377
# Iter 72/500 - Loss: -5.917
# SE_k: sigma: 0.291  gamma: 3.426  A: 0.427
# SE_r: sigma: 0.918  gamma: 2.379
# Iter 73/500 - Loss: -5.916
# SE_k: sigma: 0.291  gamma: 3.427  A: 0.428
# SE_r: sigma: 0.917  gamma: 2.381
# Iter 74/500 - Loss: -5.916
# SE_k: sigma: 0.291  gamma: 3.427  A: 0.428
# SE_r: sigma: 0.917  gamma: 2.381
# Iter 75/500 - Loss: -5.917
# SE_k: sigma: 0.291  gamma: 3.426  A: 0.428
# SE_r: sigma: 0.918  gamma: 2.381
# Iter 76/500 - Loss: -5.917
# SE_k: sigma: 0.291  gamma: 3.425  A: 0.427
# SE_r: sigma: 0.919  gamma: 2.380
# Iter 77/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.424  A: 0.427
# SE_r: sigma: 0.920  gamma: 2.379
# Iter 78/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.423  A: 0.427
# SE_r: sigma: 0.921  gamma: 2.379
# Iter 79/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.422  A: 0.427
# SE_r: sigma: 0.921  gamma: 2.378
# Iter 80/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.423  A: 0.427
# SE_r: sigma: 0.921  gamma: 2.379
# Iter 81/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.424  A: 0.427
# SE_r: sigma: 0.920  gamma: 2.380
# Iter 82/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.426  A: 0.428
# SE_r: sigma: 0.919  gamma: 2.381
# Iter 83/500 - Loss: -5.917
# SE_k: sigma: 0.291  gamma: 3.427  A: 0.428
# SE_r: sigma: 0.918  gamma: 2.381
# Iter 84/500 - Loss: -5.917
# SE_k: sigma: 0.291  gamma: 3.428  A: 0.428
# SE_r: sigma: 0.918  gamma: 2.382
# Iter 85/500 - Loss: -5.917
# SE_k: sigma: 0.291  gamma: 3.428  A: 0.428
# SE_r: sigma: 0.918  gamma: 2.381
# Iter 86/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.427  A: 0.428
# SE_r: sigma: 0.918  gamma: 2.380
# Iter 87/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.427  A: 0.427
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 88/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.426  A: 0.427
# SE_r: sigma: 0.919  gamma: 2.378
# Iter 89/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.426  A: 0.427
# SE_r: sigma: 0.919  gamma: 2.377
# Iter 90/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.427  A: 0.427
# SE_r: sigma: 0.919  gamma: 2.377
# Iter 91/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.428  A: 0.427
# SE_r: sigma: 0.918  gamma: 2.378
# Iter 92/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.429  A: 0.427
# SE_r: sigma: 0.918  gamma: 2.378
# Iter 93/500 - Loss: -5.917
# SE_k: sigma: 0.291  gamma: 3.429  A: 0.427
# SE_r: sigma: 0.918  gamma: 2.379
# Iter 94/500 - Loss: -5.917
# SE_k: sigma: 0.291  gamma: 3.430  A: 0.427
# SE_r: sigma: 0.918  gamma: 2.379
# Iter 95/500 - Loss: -5.917
# SE_k: sigma: 0.291  gamma: 3.429  A: 0.427
# SE_r: sigma: 0.918  gamma: 2.379
# Iter 96/500 - Loss: -5.917
# SE_k: sigma: 0.291  gamma: 3.429  A: 0.427
# SE_r: sigma: 0.918  gamma: 2.378
# Iter 97/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.429  A: 0.427
# SE_r: sigma: 0.919  gamma: 2.378
# Iter 98/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.428  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.378
# Iter 99/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.428  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.378
# Iter 100/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.428  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.378
# Iter 101/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.429  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.378
# Iter 102/500 - Loss: -5.917
# SE_k: sigma: 0.291  gamma: 3.429  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 103/500 - Loss: -5.917
# SE_k: sigma: 0.291  gamma: 3.430  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 104/500 - Loss: -5.917
# SE_k: sigma: 0.291  gamma: 3.430  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 105/500 - Loss: -5.917
# SE_k: sigma: 0.291  gamma: 3.430  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 106/500 - Loss: -5.917
# SE_k: sigma: 0.291  gamma: 3.429  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 107/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.429  A: 0.426
# SE_r: sigma: 0.920  gamma: 2.379
# Iter 108/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.429  A: 0.426
# SE_r: sigma: 0.920  gamma: 2.378
# Iter 109/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.429  A: 0.426
# SE_r: sigma: 0.920  gamma: 2.378
# Iter 110/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.430  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 111/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.430  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 112/500 - Loss: -5.917
# SE_k: sigma: 0.291  gamma: 3.430  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 113/500 - Loss: -5.917
# SE_k: sigma: 0.291  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 114/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 115/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.430  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 116/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.430  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 117/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.430  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.378
# Iter 118/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.430  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.378
# Iter 119/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.378
# Iter 120/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 121/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 122/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 123/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 124/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 125/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 126/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 127/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 128/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 129/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 130/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 131/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 132/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 133/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 134/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 135/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 136/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 137/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 138/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 139/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 140/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 141/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 142/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 143/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 144/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 145/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 146/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.431  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 147/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 148/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 149/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 150/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 151/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 152/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 153/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 154/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 155/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 156/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 157/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 158/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 159/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 160/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 161/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 162/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 163/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 164/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 165/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 166/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 167/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 168/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 169/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 170/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 171/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 172/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 173/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 174/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 175/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 176/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 177/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 178/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 179/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 180/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 181/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 182/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 183/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 184/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 185/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 186/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 187/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 188/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 189/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 190/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 191/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 192/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 193/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 194/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 195/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 196/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 197/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 198/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 199/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 200/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 201/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 202/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 203/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 204/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 205/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 206/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 207/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 208/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 209/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 210/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 211/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 212/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 213/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 214/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 215/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 216/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 217/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 218/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 219/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 220/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 221/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 222/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 223/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 224/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 225/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 226/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 227/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 228/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 229/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 230/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 231/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 232/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 233/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 234/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 235/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 236/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 237/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 238/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 239/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 240/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 241/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 242/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 243/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 244/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 245/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 246/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 247/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 248/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 249/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 250/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 251/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 252/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 253/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 254/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 255/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 256/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 257/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 258/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 259/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 260/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 261/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 262/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 263/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 264/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 265/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 266/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 267/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 268/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 269/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 270/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 271/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 272/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 273/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 274/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 275/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 276/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 277/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 278/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 279/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 280/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 281/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 282/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 283/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 284/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 285/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 286/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 287/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 288/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 289/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 290/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 291/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 292/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 293/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 294/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 295/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 296/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 297/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 298/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 299/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 300/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 301/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 302/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 303/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 304/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 305/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 306/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 307/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 308/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 309/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 310/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 311/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 312/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 313/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 314/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 315/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 316/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 317/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 318/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 319/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 320/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 321/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 322/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 323/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 324/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 325/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 326/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 327/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 328/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 329/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 330/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 331/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 332/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 333/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 334/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 335/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 336/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 337/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 338/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 339/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 340/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 341/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 342/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 343/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 344/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 345/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 346/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 347/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 348/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 349/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 350/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 351/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 352/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 353/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 354/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 355/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 356/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 357/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 358/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 359/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 360/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 361/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 362/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 363/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 364/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 365/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 366/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 367/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 368/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 369/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 370/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 371/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 372/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 373/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 374/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 375/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 376/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 377/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 378/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 379/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 380/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 381/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 382/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 383/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 384/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 385/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 386/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 387/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 388/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 389/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 390/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 391/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 392/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 393/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 394/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 395/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 396/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 397/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 398/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 399/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 400/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 401/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 402/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 403/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 404/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 405/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 406/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 407/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 408/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 409/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 410/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 411/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 412/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 413/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 414/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 415/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 416/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 417/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 418/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 419/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 420/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 421/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 422/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 423/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 424/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 425/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 426/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 427/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 428/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 429/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 430/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 431/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 432/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 433/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 434/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 435/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 436/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 437/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 438/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 439/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 440/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 441/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 442/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 443/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 444/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 445/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 446/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 447/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 448/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 449/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 450/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 451/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 452/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 453/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 454/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 455/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 456/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 457/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 458/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 459/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 460/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 461/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 462/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 463/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 464/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 465/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 466/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 467/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 468/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 469/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 470/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 471/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 472/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 473/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 474/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 475/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 476/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 477/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 478/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 479/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 480/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 481/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 482/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 483/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 484/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 485/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 486/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 487/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 488/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 489/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 490/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 491/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 492/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 493/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 494/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 495/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 496/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 497/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 498/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 499/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
# Iter 500/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379

# %%
print("Final State:")
print('Iter %d/%d - Loss: %.3f\nSE_k: sigma: %.3f  gamma: %.3f  A: %.3f\nSE_r: sigma: %.3f  gamma: %.3f' % (
        i + 1, training_iter, loss.item(),
        model.nm0.kernels[0].sigma.item(),
        model.nm0.kernels[0].gamma.item(),
        model.nm0.kernels[0].A.item(),
        model.nm0.kernels[1].sigma.item(),
        model.nm0.kernels[1].gamma.item(),
    ))
# Out:
# Final State:
# Iter 500/500 - Loss: -5.917
# SE_k: sigma: 0.292  gamma: 3.432  A: 0.426
# SE_r: sigma: 0.919  gamma: 2.379
